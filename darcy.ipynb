# %%
# !pip install neuraloperator
# Out:
# Collecting neuraloperator
#   Downloading neuraloperator-1.0.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from neuraloperator) (0.22.2)
# Collecting ruamel-yaml (from neuraloperator)
#   Downloading ruamel.yaml-0.18.15-py3-none-any.whl.metadata (25 kB)
# Collecting configmypy (from neuraloperator)
#   Downloading configmypy-0.2.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting tensorly (from neuraloperator)
#   Downloading tensorly-0.9.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting tensorly-torch (from neuraloperator)
#   Downloading tensorly_torch-0.5.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting torch-harmonics==0.7.3 (from neuraloperator)
#   Downloading torch_harmonics-0.7.3.tar.gz (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 29.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from neuraloperator) (3.10.0)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/dist-packages (from neuraloperator) (2.0.2)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.12/dist-packages (from neuraloperator) (3.4.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from neuraloperator) (3.14.0)
# Collecting zarr (from neuraloperator)
#   Downloading zarr-3.1.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from torch-harmonics==0.7.3->neuraloperator) (2.8.0+cu126)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from configmypy->neuraloperator) (8.4.2)
# Collecting pytest-mock (from configmypy->neuraloperator)
#   Downloading pytest_mock-3.15.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->neuraloperator) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->neuraloperator) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->neuraloperator) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->neuraloperator) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->neuraloperator) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->neuraloperator) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->neuraloperator) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->neuraloperator) (2.9.0.post0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel-yaml->neuraloperator)
#   Downloading ruamel.yaml.clib-0.2.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from tensorly->neuraloperator) (1.16.2)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb->neuraloperator) (8.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->neuraloperator) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb->neuraloperator) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb->neuraloperator) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb->neuraloperator) (2.11.10)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb->neuraloperator) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->neuraloperator) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->neuraloperator) (2.40.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb->neuraloperator) (4.15.0)
# Collecting donfig>=0.8 (from zarr->neuraloperator)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Collecting numcodecs>=0.14 (from numcodecs[crc32c]>=0.14->zarr->neuraloperator)
#   Downloading numcodecs-0.16.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->neuraloperator) (4.0.12)
# Collecting crc32c>=2.7 (from numcodecs[crc32c]>=0.14->zarr->neuraloperator)
#   Downloading crc32c-2.7.1.post0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->neuraloperator) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->neuraloperator) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->neuraloperator) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->neuraloperator) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb->neuraloperator) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb->neuraloperator) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb->neuraloperator) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb->neuraloperator) (2025.10.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (3.4.0)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest->configmypy->neuraloperator) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest->configmypy->neuraloperator) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest->configmypy->neuraloperator) (2.19.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->neuraloperator) (5.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4.0->torch-harmonics==0.7.3->neuraloperator) (3.0.3)
# Downloading neuraloperator-1.0.2-py3-none-any.whl (186 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.9/186.9 kB 14.5 MB/s eta 0:00:00
# Downloading configmypy-0.2.0-py3-none-any.whl (14 kB)
# Downloading ruamel.yaml-0.18.15-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 9.9 MB/s eta 0:00:00
# Downloading tensorly-0.9.0-py3-none-any.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 81.3 MB/s eta 0:00:00
# Downloading tensorly_torch-0.5.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.3/59.3 kB 4.1 MB/s eta 0:00:00
# Downloading zarr-3.1.3-py3-none-any.whl (276 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 22.9 MB/s eta 0:00:00
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 118.7 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (753 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.1/753.1 kB 50.6 MB/s eta 0:00:00
# Downloading pytest_mock-3.15.1-py3-none-any.whl (10 kB)
# Downloading crc32c-2.7.1.post0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 7.1 MB/s eta 0:00:00
# Building wheels for collected packages: torch-harmonics
#   Building wheel for torch-harmonics (pyproject.toml) ... done
#   Created wheel for torch-harmonics: filename=torch_harmonics-0.7.3-py3-none-any.whl size=87749 sha256=6a25f3b9c223a11388e36dcadcd7ff846000f040d2b0eb24d256e3e9dfe36693
#   Stored in directory: /root/.cache/pip/wheels/53/e5/23/5dd311b49596ed8933fba1240082719666e03b07e148f90234
# Successfully built torch-harmonics
# Installing collected packages: ruamel.yaml.clib, numcodecs, donfig, crc32c, tensorly-torch, tensorly, ruamel-yaml, pytest-mock, zarr, configmypy, torch-harmonics, neuraloperator
# Successfully installed configmypy-0.2.0 crc32c-2.7.1.post0 donfig-0.8.1.post1 neuraloperator-1.0.2 numcodecs-0.16.3 pytest-mock-3.15.1 ruamel-yaml-0.18.15 ruamel.yaml.clib-0.2.14 tensorly-0.9.0 tensorly-torch-0.5.0 torch-harmonics-0.7.3 zarr-3.1.3

# %%
# !git clone https://github.com/neuraloperator/neuraloperator.git
# Out:
# Cloning into 'neuraloperator'...
# remote: Enumerating objects: 13981, done.
# remote: Counting objects: 100% (1416/1416), done.
# remote: Compressing objects: 100% (482/482), done.
# remote: Total 13981 (delta 1158), reused 934 (delta 934), pack-reused 12565 (from 3)
# Receiving objects: 100% (13981/13981), 108.93 MiB | 54.33 MiB/s, done.
# Resolving deltas: 100% (9198/9198), done.

# %%
# !cd neuraloperator

# %%
import torch
import matplotlib.pyplot as plt
import sys
from neuralop.models import FNO
from neuralop import Trainer
from neuralop.training import AdamW
from neuralop.data.datasets import load_darcy_flow_small
from neuralop.utils import count_model_params
from neuralop import LpLoss, H1Loss

device = 'cpu'

# %%
from neuralop.data.datasets import load_darcy_flow_small
from neuralop.data.datasets.car_cfd_dataset import CarCFDDataset

# %%
train_loader, test_loaders, data_processor = load_darcy_flow_small(
        n_train=1000, batch_size=32,
        test_resolutions=[16, 32], n_tests=[100, 50],
        test_batch_sizes=[32, 32],
)
# data_processor = data_processor.to(device)
# Out:
# Loading test db for resolution 16 with 100 samples
# Loading test db for resolution 32 with 50 samples

# %%
import os

path = "/usr/local/lib/python3.12/dist-packages/neuralop/data/datasets/data"

# Split the path into folders
folders = path.split(os.sep)
print(folders)
# Out:
# ['', 'usr', 'local', 'lib', 'python3.12', 'dist-packages', 'neuralop', 'data', 'datasets', 'data']

# %%
# All items in the folder
items = os.listdir(path)

# Separate files and folders
files = [name for name in items if os.path.isfile(os.path.join(path, name))]
folders = [name for name in items if os.path.isdir(os.path.join(path, name))]

print("Files:", files)
print("Number of files:", len(files))
print("Folders:", folders)
print("Number of folders:", len(folders))
# Out:
# Files: ['darcy_test_32.pt', 'darcy_test_16.pt', 'darcy_train_16.pt']
# Number of files: 3
# Folders: []
# Number of folders: 0

# %%
model = FNO(n_modes=(16, 16),
             in_channels=1,
             out_channels=1,
             hidden_channels=32,
             projection_channel_ratio=2)
model = model.to(device)

n_params = count_model_params(model)
print(f'\nOur model has {n_params} parameters.')
sys.stdout.flush()
# Out:
# Our model has 1192801 parameters.

# %%
optimizer = AdamW(model.parameters(),
                                lr=8e-3,
                                weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=30)

# %%
l2loss = LpLoss(d=2, p=2)
h1loss = H1Loss(d=2)

train_loss = h1loss
eval_losses={'h1': h1loss, 'l2': l2loss}

# %%
print('\n### MODEL ###\n', model)
print('\n### OPTIMIZER ###\n', optimizer)
print('\n### SCHEDULER ###\n', scheduler)
print('\n### LOSSES ###')
print(f'\n * Train: {train_loss}')
print(f'\n * Test: {eval_losses}')
sys.stdout.flush()
# Out:
# ### MODEL ###
#  FNO(
#   (positional_embedding): GridEmbeddingND()
#   (fno_blocks): FNOBlocks(
#     (convs): ModuleList(
#       (0-3): 4 x SpectralConv(
#         (weight): DenseTensor(shape=torch.Size([32, 32, 16, 9]), rank=None)
#       )
#     )
#     (fno_skips): ModuleList(
#       (0-3): 4 x Flattened1dConv(
#         (conv): Conv1d(32, 32, kernel_size=(1,), stride=(1,), bias=False)
#       )
#     )
#     (channel_mlp): ModuleList(
#       (0-3): 4 x ChannelMLP(
#         (fcs): ModuleList(
#           (0): Conv1d(32, 16, kernel_size=(1,), stride=(1,))
#           (1): Conv1d(16, 32, kernel_size=(1,), stride=(1,))
#         )
#       )
#     )
#     (channel_mlp_skips): ModuleList(
#       (0-3): 4 x SoftGating()
#     )
#   )
#   (lifting): ChannelMLP(
#     (fcs): ModuleList(
#       (0): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#       (1): Conv1d(64, 32, kernel_size=(1,), stride=(1,))
#     )
#   )
#   (projection): ChannelMLP(
#     (fcs): ModuleList(
#       (0): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#       (1): Conv1d(64, 1, kernel_size=(1,), stride=(1,))
#     )
#   )
# )
#
# ### OPTIMIZER ###
#  AdamW (
# Parameter Group 0
#     betas: (0.9, 0.999)
#     correct_bias: True
#     eps: 1e-06
#     initial_lr: 0.008
#     lr: 0.008
#     weight_decay: 0.0001
# )
#
# ### SCHEDULER ###
#  <torch.optim.lr_scheduler.CosineAnnealingLR object at 0x78f0d081cda0>
#
# ### LOSSES ###
#
#  * Train: <neuralop.losses.data_losses.H1Loss object at 0x78f0d09a3920>
#
#  * Test: {'h1': <neuralop.losses.data_losses.H1Loss object at 0x78f0d09a3920>, 'l2': <neuralop.losses.data_losses.LpLoss object at 0x78f0d09a3560>}

# %%
trainer = Trainer(model=model, n_epochs=20,
                  device=device,
                  data_processor=data_processor,
                  wandb_log=False,
                  eval_interval=3,
                  use_distributed=False,
                  verbose=True)

# %%
trainer.train(train_loader=train_loader,
              test_loaders=test_loaders,
              optimizer=optimizer,
              scheduler=scheduler,
              regularizer=False,
              training_loss=train_loss,
              eval_losses=eval_losses)
# Out:
# Training on 1000 samples
# Testing on [50, 50] samples         on resolutions [16, 32].
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.12/dist-packages/tltorch/factorized_tensors/factorized_tensors.py:66: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
#   return self.__class__(self.tensor[indices])
# /usr/local/lib/python3.12/dist-packages/neuralop/layers/spectral_convolution.py:468: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
#   out_fft[slices_x] = self._contract(x[slices_x], weight, separable=self.separable)
# Raw outputs of shape torch.Size([32, 1, 16, 16])
# [0] time=7.19, avg_loss=0.5967, train_err=18.6459
# Eval: 16_h1=0.3751, 16_l2=0.2541, 32_h1=0.5426, 32_l2=0.2676
# [3] time=5.61, avg_loss=0.2105, train_err=6.5793
# Eval: 16_h1=0.2001, 16_l2=0.1388, 32_h1=0.4773, 32_l2=0.1774
# [6] time=6.04, avg_loss=0.1764, train_err=5.5137
# Eval: 16_h1=0.2341, 16_l2=0.1643, 32_h1=0.4901, 32_l2=0.2013
# [9] time=6.43, avg_loss=0.1792, train_err=5.6012
# Eval: 16_h1=0.2126, 16_l2=0.1377, 32_h1=0.4660, 32_l2=0.1645
# [12] time=5.68, avg_loss=0.1339, train_err=4.1833
# Eval: 16_h1=0.2182, 16_l2=0.1291, 32_h1=0.5305, 32_l2=0.1642
# [15] time=6.28, avg_loss=0.1211, train_err=3.7854
# Eval: 16_h1=0.2271, 16_l2=0.1393, 32_h1=0.4704, 32_l2=0.1695
# [18] time=5.63, avg_loss=0.0976, train_err=3.0501
# Eval: 16_h1=0.1945, 16_l2=0.1119, 32_h1=0.4996, 32_l2=0.1520
# {'train_err': 2.884589731693268,
#  'avg_loss': 0.09230687141418457,
#  'avg_lasso_loss': None,
#  'epoch_train_time': 6.280732410999917}

# %%
test_samples = test_loaders[16].dataset

fig = plt.figure(figsize=(7, 7))
for index in range(3):
    data = test_samples[index]
    data = data_processor.preprocess(data, batched=False)
    # Input x
    x = data['x']
    # Ground-truth
    y = data['y']
    # Model prediction
    out = model(x.unsqueeze(0))

    ax = fig.add_subplot(3, 3, index*3 + 1)
    ax.imshow(x[0], cmap='gray')
    if index == 0:
        ax.set_title('Input x')
    plt.xticks([], [])
    plt.yticks([], [])

    ax = fig.add_subplot(3, 3, index*3 + 2)
    ax.imshow(y.squeeze())
    if index == 0:
        ax.set_title('Ground-truth y')
    plt.xticks([], [])
    plt.yticks([], [])

    ax = fig.add_subplot(3, 3, index*3 + 3)
    ax.imshow(out.squeeze().detach().numpy())
    if index == 0:
        ax.set_title('Model prediction')
    plt.xticks([], [])
    plt.yticks([], [])

fig.suptitle('Inputs, ground-truth output and prediction (16x16).', y=0.98)
plt.tight_layout()
fig.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/tltorch/factorized_tensors/factorized_tensors.py:66: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
#   return self.__class__(self.tensor[indices])
# /usr/local/lib/python3.12/dist-packages/neuralop/layers/spectral_convolution.py:468: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
#   out_fft[slices_x] = self._contract(x[slices_x], weight, separable=self.separable)
# /usr/local/lib/python3.12/dist-packages/tltorch/factorized_tensors/factorized_tensors.py:66: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
#   return self.__class__(self.tensor[indices])
# /usr/local/lib/python3.12/dist-packages/neuralop/layers/spectral_convolution.py:468: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
#   out_fft[slices_x] = self._contract(x[slices_x], weight, separable=self.separable)

# %%
test_samples = test_loaders[32].dataset

fig = plt.figure(figsize=(7, 7))
for index in range(3):
    data = test_samples[index]
    data = data_processor.preprocess(data, batched=False)
    # Input x
    x = data['x']
    # Ground-truth
    y = data['y']
    # Model prediction
    out = model(x.unsqueeze(0))

    ax = fig.add_subplot(3, 3, index*3 + 1)
    ax.imshow(x[0], cmap='gray')
    if index == 0:
        ax.set_title('Input x')
    plt.xticks([], [])
    plt.yticks([], [])

    ax = fig.add_subplot(3, 3, index*3 + 2)
    ax.imshow(y.squeeze())
    if index == 0:
        ax.set_title('Ground-truth y')
    plt.xticks([], [])
    plt.yticks([], [])

    ax = fig.add_subplot(3, 3, index*3 + 3)
    ax.imshow(out.squeeze().detach().numpy())
    if index == 0:
        ax.set_title('Model prediction')
    plt.xticks([], [])
    plt.yticks([], [])

fig.suptitle('Inputs, ground-truth output and prediction (32x32).', y=0.98)
plt.tight_layout()
fig.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/tltorch/factorized_tensors/factorized_tensors.py:66: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
#   return self.__class__(self.tensor[indices])
# /usr/local/lib/python3.12/dist-packages/neuralop/layers/spectral_convolution.py:468: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
#   out_fft[slices_x] = self._contract(x[slices_x], weight, separable=self.separable)
# /usr/local/lib/python3.12/dist-packages/tltorch/factorized_tensors/factorized_tensors.py:66: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
#   return self.__class__(self.tensor[indices])
# /usr/local/lib/python3.12/dist-packages/neuralop/layers/spectral_convolution.py:468: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
#   out_fft[slices_x] = self._contract(x[slices_x], weight, separable=self.separable)
# /usr/local/lib/python3.12/dist-packages/tltorch/factorized_tensors/factorized_tensors.py:66: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
#   return self.__class__(self.tensor[indices])
# /usr/local/lib/python3.12/dist-packages/neuralop/layers/spectral_convolution.py:468: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
#   out_fft[slices_x] = self._contract(x[slices_x], weight, separable=self.separable)

# %%
# import shutil
# shutil.move('/content/darcy_test_32.pt',path)
# Out:
# '/usr/local/lib/python3.12/dist-packages/neuralop/data/datasets/data/darcy_test_32.pt'
